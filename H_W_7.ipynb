# %% [markdown]
# <a href="https://colab.research.google.com/github/Deniska122334/A-B-testing-H_W/blob/main/H_W_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Решение
#
#
# *   Гипотеза №8 - Улучшение процесса доставки (392)
# *   Гипотеза №2 - Предоставление подробной информации о продукте (336)

# %% [markdown]
# 1. Улучшение процесса доставки.
#
# - Регулярно обновлять и проверять системы безопасности и механизмы защиты клиентских данных на сайте.
# - Обеспечить жесткий контроль доступа к информации о доставке и логистическим системам для предотвращения несанкционированного доступа.
# - Провести обучение сотрудников о мерах защиты и соблюдения политики конфиденциальности клиентских данных.
# - Активно сотрудничать с логистическими партнерами для обеспечения безопасности и прозрачности процесса доставки заказов.
# - Реализация политики конфиденциальности и обучение сотрудников ozon.ru о необходимости соблюдения и защиты конфиденциальной информации клиентов.
# - Реализация мер для предотвращения несанкционированного доступа к информации о доставке, таких как строгий контроль доступа к базе данных или логистическим системам.
# - Обеспечение безопасности конфиденциальных данных клиентов путем использования шифрования и защиты при обработке и передачи этих данных.

# %% [markdown]
# 2. Предоставление подробной информации о продукте.
#
# - Обеспечить правильное сохранение и защиту конфиденциальной информации о клиентах, такой как платежные данные и доставочные адреса.
# - Обучить сотрудников  о необходимости соблюдения правил конфиденциальности и предотвращения ситуаций Peekin Problem.
# - Регулярно проверять и обновлять системы безопасности и механизмы защиты информации на сайте.
# - Включить политику конфиденциальности и инструкции по обращению с конфиденциальной информацией на сайте, чтобы они были доступны и ясны для всех пользователей и сотрудников.
